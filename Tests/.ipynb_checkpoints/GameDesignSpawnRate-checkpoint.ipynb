# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
p = np.linspace(0, 10000)
y = 0.9996**p
plt.plot(p, y)
# Out:
# <img src="data:image/png;base64,..." width="640">
