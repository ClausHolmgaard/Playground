# %%
import os
import cv2
import time
import pickle
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
from SqueezeDetHelpers import get_all_points_from_prediction
from Models.PoolingAndFire import create_loss_function_multiple_detection
from PreProcess import *

# %%
#MODEL_FILE = os.path.expanduser("~/results/SqueezeDet/all_points_multi_gpu.h5py")
#MODEL_FILE = os.path.expanduser("~/results/SqueezeDet/all_points_complete_run_09.h5py")
MODEL_FILE = os.path.expanduser("~/results/SqueezeDet/all_points_overfit_32.h5py")
RHD_ANNOTATIONS_FILE = os.path.expanduser("~/datasets/RHD/RHD_published_v2/training/anno_training.pickle")
VALIDATION_DIR = os.path.expanduser("~/datasets/RHD/processed/validation")
TRAIN_DIR = os.path.expanduser("~/datasets/RHD/processed/train")
VALIDATION_ANNOTATIONS = os.path.expanduser("~/datasets/RHD/processed/validation/annotations/")
TRAIN_ANNOTATIONS = os.path.expanduser("~/datasets/RHD/processed/train/annotations/")

# %%
create_rhd_annotations(RHD_ANNOTATIONS_FILE,
                       VALIDATION_ANNOTATIONS,
                       VALIDATION_DIR,
                       fingers='ALL',
                       hands_to_annotate='BOTH',
                       annotate_non_visible=False,
                       force_new_files=True)
# Out:
#  12%|█▏        | 498/4126 [00:00<00:00, 4975.95it/s]
# Creating annotations in directory: /home/clh/datasets/RHD/processed/validation
# Using annotation file: /home/clh/datasets/RHD/RHD_published_v2/training/anno_training.pickle
# And outputting to: /home/clh/datasets/RHD/processed/validation/annotations/
# 100%|██████████| 4126/4126 [00:00<00:00, 5153.53it/s]

# %%
BATCHSIZE = 64
EPSILON = 1e-16

LABEL_WEIGHT = 1.0
OFFSET_LOSS_WEIGHT = 1.0
OFFSET_SCALE = int(320 / 20) / 2

NUM_CLASSES = 42

l = create_loss_function_multiple_detection(20,
                                            20,
                                            LABEL_WEIGHT,
                                            OFFSET_SCALE,
                                            OFFSET_LOSS_WEIGHT,
                                            NUM_CLASSES,
                                            EPSILON,
                                            BATCHSIZE)

# %%
model = load_model(MODEL_FILE, custom_objects={'loss_function': l})

# %%
samples_dir = TRAIN_DIR
annotations_dir = TRAIN_ANNOTATIONS

# %%
NUM_SAMPLES_TO_CHECK = 10

samples_to_check = []
for fi in os.listdir(samples_dir):
    if fi.endswith('png'):
        samples_to_check.append(int(fi.split('.')[0]))
        if len(samples_to_check) >= NUM_SAMPLES_TO_CHECK:
            break

print(samples_to_check)
# Out:
# [2671, 13691, 11388, 16081, 2962, 29984, 15841, 2587, 22410, 33917]

# %%
#labels, images = load_data_with_anchors(samples_to_check,
#                                        DATA_DIR,
#                                        ANNOTATIONS_PATH,
#                                        320, 320,
#                                        20, 20,
#                                        'png',
#                                        num_classes=NUM_CLASSES)

#overfit_sample = [0]
#samples_to_check = overfit_sample
labels, images = load_data_with_anchors(samples_to_check,
                                        samples_dir,
                                        annotations_dir,
                                        320, 320,
                                        20, 20,
                                        OFFSET_SCALE,
                                        'png',
                                        num_classes=NUM_CLASSES,
                                        greyscale=True)

images_show = np.zeros((len(images), 320, 320, 3), dtype=np.uint8)
for c, im in enumerate(images):
    #images_show[c] = cv2.cvtColor((im * 255.0).astype(np.uint8), cv2.COLOR_BGR2RGB)
    images_show[c][:, :, 0] = im.reshape(320, 320) * 255.0
    images_show[c][:, :, 1] = im.reshape(320, 320) * 255.0
    images_show[c][:, :, 2] = im.reshape(320, 320) * 255.0

print(np.max(images[0]))
# Out:
# 0.9294117647058824

# %%
for l in labels:
    print(l.shape)
    for i in range(NUM_CLASSES):
        offset_xs = l[:, :, NUM_CLASSES+i*2]
        offset_ys = l[:, :, NUM_CLASSES+1+i*2]
        
        print(f"Offset max x: {np.max(offset_xs)}")
        print(f"Offset max y: {np.max(offset_ys)}")
        print("")
# Out:
# (20, 20, 126)
# Offset max x: 2.1875
# Offset max y: 1.7999992370605469
#
# Offset max x: 1.2374992370605469
# Offset max y: 1.4624996185302734
#
# Offset max x: 2.0375003814697266
# Offset max y: 1.9125003814697266
#
# Offset max x: 2.2875003814697266
# Offset max y: 2.3999996185302734
#
# Offset max x: 1.3875007629394531
# Offset max y: 2.262500762939453
#
# Offset max x: 2.174999237060547
# Offset max y: 2.2749996185302734
#
# Offset max x: 0.9249992370605469
# Offset max y: 1.9750003814697266
#
# Offset max x: 1.5375003814697266
# Offset max y: 1.75
#
# Offset max x: 1.8125
# Offset max y: 1.2625007629394531
#
# Offset max x: 1.0750007629394531
# Offset max y: 2.387500762939453
#
# Offset max x: 1.4624996185302734
# Offset max y: 2.637500762939453
#
# Offset max x: 1.8999996185302734
# Offset max y: 2.7250003814697266
#
# Offset max x: 1.9874992370605469
# Offset max y: 2.4624996185302734
#
# Offset max x: 2.375
# Offset max y: 2.512500762939453
#
# Offset max x: 1.1000003814697266
# Offset max y: 1.1124992370605469
#
# Offset max x: 1.6749992370605469
# Offset max y: 1.3999996185302734
#
# Offset max x: 1.9750003814697266
# Offset max y: 1.3125
#
# Offset max x: 1.2374992370605469
# Offset max y: 1.25
#
# Offset max x: 2.375
# Offset max y: 1.6875
#
# Offset max x: 1.5750007629394531
# Offset max y: 1.8999996185302734
#
# Offset max x: 1.8875007629394531
# Offset max y: 1.8999996185302734
#
# Offset max x: 1.0499992370605469
# Offset max y: 1.7875003814697266
#
# Offset max x: 2.125
# Offset max y: 0.8999996185302734
#
# Offset max x: 1.4124984741210938
# Offset max y: 2.237499237060547
#
# Offset max x: 0.7625007629394531
# Offset max y: 1.2999992370605469
#
# Offset max x: 1.875
# Offset max y: 2.2875003814697266
#
# Offset max x: 0.9874992370605469
# Offset max y: 0.9500007629394531
#
# Offset max x: 2.549999237060547
# Offset max y: 1.8999996185302734
#
# Offset max x: 2.237499237060547
# Offset max y: 1.0874996185302734
#
# Offset max x: 1.5125007629394531
# Offset max y: 2.0249996185302734
#
# Offset max x: 1.9625015258789062
# Offset max y: 1.2250003814697266
#
# Offset max x: 1.8499984741210938
# Offset max y: 2.237499237060547
#
# Offset max x: 1.7249984741210938
# Offset max y: 1.3250007629394531
#
# Offset max x: 1.1500015258789062
# Offset max y: 2.25
#
# Offset max x: 0.9249992370605469
# Offset max y: 1.0125007629394531
#
# Offset max x: 0.9375
# Offset max y: 2.0874996185302734
#
# Offset max x: 0.9124984741210938
# Offset max y: 1.25
#
# Offset max x: 2.612499237060547
# Offset max y: 2.299999237060547
#
# Offset max x: 1.9625015258789062
# Offset max y: 2.3500003814697266
#
# Offset max x: 2.0250015258789062
# Offset max y: 1.7999992370605469
#
# Offset max x: 2.075000762939453
# Offset max y: 1.2749996185302734
#
# Offset max x: 1.8624992370605469
# Offset max y: 2.3125
#
# (20, 20, 126)
# Offset max x: 2.0249996185302734
# Offset max y: 1.7625007629394531
#
# Offset max x: 0.9500007629394531
# Offset max y: 1.6124992370605469
#
# Offset max x: 2.200000762939453
# Offset max y: 1.6875
#
# Offset max x: 2.237499237060547
# Offset max y: 1.2625007629394531
#
# Offset max x: 2.3500003814697266
# Offset max y: 1.0249996185302734
#
# Offset max x: 2.3125
# Offset max y: 1.5499992370605469
#
# Offset max x: 1.8250007629394531
# Offset max y: 2.4624996185302734
#
# Offset max x: 1.2250003814697266
# Offset max y: 1.2250003814697266
#
# Offset max x: 2.375
# Offset max y: 2.325000762939453
#
# Offset max x: 2.3999996185302734
# Offset max y: 1.3999996185302734
#
# Offset max x: 1.8250007629394531
# Offset max y: 1.125
#
# Offset max x: 1.1875
# Offset max y: 1.9125003814697266
#
# Offset max x: 2.5625
# Offset max y: 0.9375
#
# Offset max x: 0.875
# Offset max y: 1.0249996185302734
#
# Offset max x: 2.0375003814697266
# Offset max y: 1.125
#
# Offset max x: 1.3250007629394531
# Offset max y: 1.7124996185302734
#
# Offset max x: 1.2875003814697266
# Offset max y: 1.1625003814697266
#
# Offset max x: 0.9624996185302734
# Offset max y: 1.1749992370605469
#
# Offset max x: 2.2250003814697266
# Offset max y: 1.0625
#
# Offset max x: 1.7000007629394531
# Offset max y: 2.0
#
# Offset max x: 2.125
# Offset max y: 1.2124996185302734
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# (20, 20, 126)
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 2.0
# Offset max y: 0.9624996185302734
#
# Offset max x: 2.0850000381469727
# Offset max y: 2.7875003814697266
#
# Offset max x: 1.4562501907348633
# Offset max y: 1.8625001907348633
#
# Offset max x: 1.3874998092651367
# Offset max y: 2.4875001907348633
#
# Offset max x: 1.9499998092651367
# Offset max y: 1.6749992370605469
#
# Offset max x: 1.6337499618530273
# Offset max y: 1.0
#
# Offset max x: 1.5012502670288086
# Offset max y: 2.5749998092651367
#
# Offset max x: 1.2375001907348633
# Offset max y: 2.375
#
# Offset max x: 1.1374998092651367
# Offset max y: 2.4875001907348633
#
# Offset max x: 2.676250457763672
# Offset max y: 1.5874996185302734
#
# Offset max x: 2.4825000762939453
# Offset max y: 0.9125003814697266
#
# Offset max x: 2.3374996185302734
# Offset max y: 2.0874996185302734
#
# Offset max x: 2.0625
# Offset max y: 1.75
#
# Offset max x: 1.7725000381469727
# Offset max y: 1.5625
#
# Offset max x: 1.5500001907348633
# Offset max y: 2.6000003814697266
#
# Offset max x: 1.2624998092651367
# Offset max y: 1.7374992370605469
#
# Offset max x: 2.6499996185302734
# Offset max y: 0.8999996185302734
#
# Offset max x: 1.7250003814697266
# Offset max y: 2.625
#
# Offset max x: 2.7250003814697266
# Offset max y: 1.9874992370605469
#
# Offset max x: 1.8000001907348633
# Offset max y: 1.3875007629394531
#
# Offset max x: 1.1875
# Offset max y: 2.3125
#
# (20, 20, 126)
# Offset max x: 2.3249998092651367
# Offset max y: 1.9874992370605469
#
# Offset max x: 1.6625003814697266
# Offset max y: 1.4750003814697266
#
# Offset max x: 0.9500007629394531
# Offset max y: 2.25
#
# Offset max x: 0.9874992370605469
# Offset max y: 1.5499992370605469
#
# Offset max x: 2.7250003814697266
# Offset max y: 2.4125003814697266
#
# Offset max x: 1.2625007629394531
# Offset max y: 1.6499996185302734
#
# Offset max x: 1.8250007629394531
# Offset max y: 2.0874996185302734
#
# Offset max x: 2.3374996185302734
# Offset max y: 2.6875
#
# Offset max x: 2.2749996185302734
# Offset max y: 1.3999996185302734
#
# Offset max x: 1.7875003814697266
# Offset max y: 2.112499237060547
#
# Offset max x: 2.25
# Offset max y: 2.387500762939453
#
# Offset max x: 2.6625003814697266
# Offset max y: 2.6625003814697266
#
# Offset max x: 0.9500007629394531
# Offset max y: 0.8125
#
# Offset max x: 2.6125001907348633
# Offset max y: 2.6875
#
# Offset max x: 2.049999237060547
# Offset max y: 2.012500762939453
#
# Offset max x: 0.8999996185302734
# Offset max y: 2.4750003814697266
#
# Offset max x: 1.3875007629394531
# Offset max y: 1.5249996185302734
#
# Offset max x: 1.75
# Offset max y: 1.3624992370605469
#
# Offset max x: 2.6625003814697266
# Offset max y: 2.700000762939453
#
# Offset max x: 1.2374992370605469
# Offset max y: 1.0874996185302734
#
# Offset max x: 1.8875007629394531
# Offset max y: 2.0249996185302734
#
# Offset max x: 1.9000015258789062
# Offset max y: 1.0125007629394531
#
# Offset max x: 1.625
# Offset max y: 1.4500007629394531
#
# Offset max x: 1.9249992370605469
# Offset max y: 2.424999237060547
#
# Offset max x: 2.200000762939453
# Offset max y: 1.3125
#
# Offset max x: 1.0625
# Offset max y: 1.8250007629394531
#
# Offset max x: 1.625
# Offset max y: 1.0875015258789062
#
# Offset max x: 2.3374996185302734
# Offset max y: 2.4749984741210938
#
# Offset max x: 1.0
# Offset max y: 1.7874984741210938
#
# Offset max x: 1.375
# Offset max y: 2.3999996185302734
#
# Offset max x: 1.5625
# Offset max y: 2.549999237060547
#
# Offset max x: 2.3999996185302734
# Offset max y: 2.237499237060547
#
# Offset max x: 1.3125
# Offset max y: 1.75
#
# Offset max x: 1.7874984741210938
# Offset max y: 2.4750003814697266
#
# Offset max x: 1.5874996185302734
# Offset max y: 1.625
#
# Offset max x: 2.4624996185302734
# Offset max y: 1.5499992370605469
#
# Offset max x: 1.4125003814697266
# Offset max y: 1.2124996185302734
#
# Offset max x: 1.9124984741210938
# Offset max y: 2.2124996185302734
#
# Offset max x: 2.012500762939453
# Offset max y: 2.4375
#
# Offset max x: 2.612499237060547
# Offset max y: 2.612499237060547
#
# Offset max x: 1.2999992370605469
# Offset max y: 2.549999237060547
#
# Offset max x: 1.8624992370605469
# Offset max y: 1.7625007629394531
#
# (20, 20, 126)
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.8125
# Offset max y: 1.5125007629394531
#
# Offset max x: 1.9125003814697266
# Offset max y: 0.8875007629394531
#
# Offset max x: 0.9874992370605469
# Offset max y: 0.8624992370605469
#
# Offset max x: 1.7124996185302734
# Offset max y: 1.9624996185302734
#
# Offset max x: 1.9874992370605469
# Offset max y: 2.3125
#
# Offset max x: 1.7124996185302734
# Offset max y: 1.1499996185302734
#
# Offset max x: 1.5499992370605469
# Offset max y: 0.8125
#
# Offset max x: 1.6000003814697266
# Offset max y: 1.5874996185302734
#
# Offset max x: 1.6749992370605469
# Offset max y: 2.262500762939453
#
# Offset max x: 2.549999237060547
# Offset max y: 2.2875003814697266
#
# Offset max x: 2.3125
# Offset max y: 1.8624992370605469
#
# Offset max x: 1.9750003814697266
# Offset max y: 0.8624992370605469
#
# Offset max x: 2.1499996185302734
# Offset max y: 1.375
#
# Offset max x: 1.0375003814697266
# Offset max y: 2.4624996185302734
#
# Offset max x: 0.9624996185302734
# Offset max y: 1.2749996185302734
#
# Offset max x: 0.9624996185302734
# Offset max y: 1.9375
#
# Offset max x: 2.6000003814697266
# Offset max y: 1.3875007629394531
#
# Offset max x: 1.9874992370605469
# Offset max y: 2.1875
#
# Offset max x: 2.0
# Offset max y: 2.012500762939453
#
# Offset max x: 1.8500003814697266
# Offset max y: 2.325000762939453
#
# Offset max x: 1.2875003814697266
# Offset max y: 1.8999996185302734
#
# (20, 20, 126)
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.8375015258789062
# Offset max y: 1.7999992370605469
#
# Offset max x: 1.25
# Offset max y: 2.6625003814697266
#
# Offset max x: 2.375
# Offset max y: 0.9750003814697266
#
# Offset max x: 2.3500003814697266
# Offset max y: 0.9249992370605469
#
# Offset max x: 1.5750007629394531
# Offset max y: 2.1625003814697266
#
# Offset max x: 1.3250007629394531
# Offset max y: 1.625
#
# Offset max x: 1.4249992370605469
# Offset max y: 0.9249992370605469
#
# Offset max x: 1.5
# Offset max y: 2.012500762939453
#
# Offset max x: 2.549999237060547
# Offset max y: 2.3374996185302734
#
# Offset max x: 2.0625
# Offset max y: 1.4874992370605469
#
# Offset max x: 2.5874996185302734
# Offset max y: 2.5
#
# Offset max x: 1.1000003814697266
# Offset max y: 1.5249996185302734
#
# Offset max x: 1.1375007629394531
# Offset max y: 1.8374996185302734
#
# Offset max x: 0.9624996185302734
# Offset max y: 2.237499237060547
#
# Offset max x: 0.8875007629394531
# Offset max y: 1.3624992370605469
#
# Offset max x: 0.7749996185302734
# Offset max y: 2.487499237060547
#
# Offset max x: 2.2749996185302734
# Offset max y: 2.6625003814697266
#
# Offset max x: 2.5
# Offset max y: 2.6875
#
# Offset max x: 2.637500762939453
# Offset max y: 2.0625
#
# Offset max x: 2.75
# Offset max y: 1.4874992370605469
#
# Offset max x: 2.0249996185302734
# Offset max y: 1.6625003814697266
#
# (20, 20, 126)
# Offset max x: 1.7387499809265137
# Offset max y: 1.8662500381469727
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 2.442500114440918
# Offset max y: 0.0
#
# Offset max x: 2.0437498092651367
# Offset max y: 1.3199999332427979
#
# Offset max x: 1.1262502670288086
# Offset max y: 2.3324999809265137
#
# Offset max x: 1.890000343322754
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 2.307499885559082
# Offset max y: 0.0
#
# Offset max x: 1.5825004577636719
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 1.067500114440918
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 1.4987502098083496
# Offset max y: 0.0
#
# Offset max x: 2.4300003051757812
# Offset max y: 0.0
#
# Offset max x: 1.723750114440918
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 1.2100000381469727
# Offset max y: 0.0
#
# Offset max x: 2.2875003814697266
# Offset max y: 1.0625
#
# Offset max x: 1.2124996185302734
# Offset max y: 0.75
#
# Offset max x: 1.2749996185302734
# Offset max y: 1.6000003814697266
#
# Offset max x: 1.75
# Offset max y: 2.1374998092651367
#
# Offset max x: 2.7749996185302734
# Offset max y: 1.4875001907348633
#
# Offset max x: 1.9125003814697266
# Offset max y: 1.1499996185302734
#
# Offset max x: 1.1124992370605469
# Offset max y: 1.5499992370605469
#
# Offset max x: 2.512500762939453
# Offset max y: 1.7749996185302734
#
# Offset max x: 2.512500762939453
# Offset max y: 1.9624996185302734
#
# Offset max x: 2.1625003814697266
# Offset max y: 0.9500007629394531
#
# Offset max x: 1.8374996185302734
# Offset max y: 1.0125007629394531
#
# Offset max x: 1.5249996185302734
# Offset max y: 1.2625007629394531
#
# Offset max x: 1.5249996185302734
# Offset max y: 1.5375003814697266
#
# Offset max x: 1.7250003814697266
# Offset max y: 1.9125003814697266
#
# Offset max x: 1.3374996185302734
# Offset max y: 2.049999237060547
#
# Offset max x: 0.9874992370605469
# Offset max y: 2.299999237060547
#
# Offset max x: 0.9125003814697266
# Offset max y: 2.487499237060547
#
# Offset max x: 1.8374996185302734
# Offset max y: 2.487499237060547
#
# Offset max x: 1.2000007629394531
# Offset max y: 1.0125007629394531
#
# Offset max x: 2.4750003814697266
# Offset max y: 1.6749992370605469
#
# Offset max x: 2.612499237060547
# Offset max y: 1.5499992370605469
#
# (20, 20, 126)
# Offset max x: 1.0699996948242188
# Offset max y: 2.6075000762939453
#
# Offset max x: 1.625
# Offset max y: 2.1875
#
# Offset max x: 1.1000003814697266
# Offset max y: 2.4375
#
# Offset max x: 2.3999996185302734
# Offset max y: 2.4125003814697266
#
# Offset max x: 1.2749996185302734
# Offset max y: 2.3050003051757812
#
# Offset max x: 1.8624992370605469
# Offset max y: 2.3999996185302734
#
# Offset max x: 1.2124996185302734
# Offset max y: 1.8624992370605469
#
# Offset max x: 2.4125003814697266
# Offset max y: 0.8374996185302734
#
# Offset max x: 1.75
# Offset max y: 2.799999237060547
#
# Offset max x: 1.2250003814697266
# Offset max y: 1.5
#
# Offset max x: 2.2624998092651367
# Offset max y: 1.5249996185302734
#
# Offset max x: 1.3500003814697266
# Offset max y: 0.8999996185302734
#
# Offset max x: 2.4875001907348633
# Offset max y: 1.2374992370605469
#
# Offset max x: 2.125
# Offset max y: 2.1625003814697266
#
# Offset max x: 1.1374998092651367
# Offset max y: 2.637500762939453
#
# Offset max x: 2.2124996185302734
# Offset max y: 2.3374996185302734
#
# Offset max x: 1.5500001907348633
# Offset max y: 0.9624996185302734
#
# Offset max x: 2.6125001907348633
# Offset max y: 1.0375003814697266
#
# Offset max x: 2.125
# Offset max y: 1.6124992370605469
#
# Offset max x: 1.5874996185302734
# Offset max y: 1.6625003814697266
#
# Offset max x: 2.466250419616699
# Offset max y: 2.3125
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# (20, 20, 126)
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 0.0
# Offset max y: 0.0
#
# Offset max x: 2.4750003814697266
# Offset max y: 0.7875003814697266
#
# Offset max x: 2.012500762939453
# Offset max y: 1.8624992370605469
#
# Offset max x: 1.0499992370605469
# Offset max y: 1.9375
#
# Offset max x: 1.0375003814697266
# Offset max y: 1.7124996185302734
#
# Offset max x: 2.2875003814697266
# Offset max y: 0.9125003814697266
#
# Offset max x: 1.6499996185302734
# Offset max y: 1.7124996185302734
#
# Offset max x: 1.0
# Offset max y: 2.0375003814697266
#
# Offset max x: 0.9874992370605469
# Offset max y: 1.2000007629394531
#
# Offset max x: 1.7999992370605469
# Offset max y: 2.5874996185302734
#
# Offset max x: 1.1499996185302734
# Offset max y: 2.262500762939453
#
# Offset max x: 2.0249996185302734
# Offset max y: 1.6124992370605469
#
# Offset max x: 2.487499237060547
# Offset max y: 2.0
#
# Offset max x: 1.5
# Offset max y: 2.762500762939453
#
# Offset max x: 2.575000762939453
# Offset max y: 2.4625015258789062
#
# Offset max x: 1.8999996185302734
# Offset max y: 1.8999996185302734
#
# Offset max x: 2.487499237060547
# Offset max y: 1.0
#
# Offset max x: 2.0375003814697266
# Offset max y: 2.25
#
# Offset max x: 2.200000762939453
# Offset max y: 1.2875003814697266
#
# Offset max x: 1.5
# Offset max y: 2.549999237060547
#
# Offset max x: 2.075000762939453
# Offset max y: 2.6000003814697266
#
# Offset max x: 1.8999996185302734
# Offset max y: 1.4750003814697266
#
# (20, 20, 126)
# Offset max x: 2.1125001907348633
# Offset max y: 1.1124992370605469
#
# Offset max x: 1.125
# Offset max y: 0.8875007629394531
#
# Offset max x: 1.9375
# Offset max y: 1.7124996185302734
#
# Offset max x: 2.424999237060547
# Offset max y: 2.362499237060547
#
# Offset max x: 0.9874992370605469
# Offset max y: 1.6499996185302734
#
# Offset max x: 2.325000762939453
# Offset max y: 0.9249992370605469
#
# Offset max x: 2.6000003814697266
# Offset max y: 1.0750007629394531
#
# Offset max x: 2.7250003814697266
# Offset max y: 1.3875007629394531
#
# Offset max x: 1.0874996185302734
# Offset max y: 1.1000003814697266
#
# Offset max x: 1.3624992370605469
# Offset max y: 2.3374996185302734
#
# Offset max x: 1.4375
# Offset max y: 2.4750003814697266
#
# Offset max x: 1.5625
# Offset max y: 2.762500762939453
#
# Offset max x: 1.5750007629394531
# Offset max y: 2.3125
#
# Offset max x: 1.0874996185302734
# Offset max y: 2.6499996185302734
#
# Offset max x: 1.3500003814697266
# Offset max y: 1.2000007629394531
#
# Offset max x: 1.5874996185302734
# Offset max y: 1.6625003814697266
#
# Offset max x: 1.8250007629394531
# Offset max y: 1.1124992370605469
#
# Offset max x: 2.3374996185302734
# Offset max y: 1.8374996185302734
#
# Offset max x: 1.2000007629394531
# Offset max y: 2.0625
#
# Offset max x: 1.9500007629394531
# Offset max y: 2.3374996185302734
#
# Offset max x: 2.0
# Offset max y: 1.5499992370605469
#
# Offset max x: 1.7749996185302734
# Offset max y: 2.625
#
# Offset max x: 0.9750003814697266
# Offset max y: 1.875
#
# Offset max x: 0.7625007629394531
# Offset max y: 0.9750003814697266
#
# Offset max x: 2.3999996185302734
# Offset max y: 1.8500003814697266
#
# Offset max x: 2.237499237060547
# Offset max y: 1.1749992370605469
#
# Offset max x: 2.549999237060547
# Offset max y: 0.8374996185302734
#
# Offset max x: 1.6375007629394531
# Offset max y: 1.1875
#
# Offset max x: 1.0750007629394531
# Offset max y: 1.5874996185302734
#
# Offset max x: 2.4750003814697266
# Offset max y: 1.6000003814697266
#
# Offset max x: 1.5
# Offset max y: 0.9874992370605469
#
# Offset max x: 0.8999996185302734
# Offset max y: 1.8250007629394531
#
# Offset max x: 2.3374996185302734
# Offset max y: 2.612499237060547
#
# Offset max x: 2.424999237060547
# Offset max y: 0.9624996185302734
#
# Offset max x: 1.0874996185302734
# Offset max y: 1.7000007629394531
#
# Offset max x: 2.3999996185302734
# Offset max y: 2.612499237060547
#
# Offset max x: 1.75
# Offset max y: 1.6625003814697266
#
# Offset max x: 1.9249992370605469
# Offset max y: 1.8624992370605469
#
# Offset max x: 1.2749996185302734
# Offset max y: 0.9125003814697266
#
# Offset max x: 1.9375
# Offset max y: 1.7625007629394531
#
# Offset max x: 2.6625003814697266
# Offset max y: 2.575000762939453
#
# Offset max x: 1.0874996185302734
# Offset max y: 2.700000762939453

# %%
right_hand = []
left_hand = []

with open(RHD_ANNOTATIONS_FILE, 'rb') as f:
    annotations = pickle.load(f)
    
for s in samples_to_check:
    right_hand.append(get_right_hand(s, annotations))
    left_hand.append(get_left_hand(s, annotations))

# %%
"""
for c, h in enumerate(right_hand):
    for finger, point in h.items():
        p = point[:2]
        if p[0] < 0 or p[1] < 0:
            continue
        print(f"Right hand point: ({p[0]}, {p[1]})")
        cv2.circle(images_show[c], (p[0], p[1]), 1, (0, 0, 255), thickness=1)
    
for c, h in enumerate(left_hand):
    for finger, point in h.items():
        p = point[:2]
        if p[0] < 0 or p[1] < 0:
            continue
        cv2.circle(images_show[c], (p[0], p[1]), 1, (0, 0, 255), thickness=1)
"""
# Out:
# '\nfor c, h in enumerate(right_hand):\n    for finger, point in h.items():\n        p = point[:2]\n        if p[0] < 0 or p[1] < 0:\n            continue\n        print(f"Right hand point: ({p[0]}, {p[1]})")\n        cv2.circle(images_show[c], (p[0], p[1]), 1, (0, 0, 255), thickness=1)\n    \nfor c, h in enumerate(left_hand):\n    for finger, point in h.items():\n        p = point[:2]\n        if p[0] < 0 or p[1] < 0:\n            continue\n        cv2.circle(images_show[c], (p[0], p[1]), 1, (0, 0, 255), thickness=1)\n'

# %%
res = np.zeros(labels.shape)
process_times = []
for c, im in enumerate(images):
    before = time.time()
    #res.append(model.predict(im.reshape(1, 320, 320, 1)))
    res[c] = model.predict(im.reshape(1, 320, 320, 1))
    process_times.append(time.time() - before)
    
process_times = np.array(process_times)
print(f"Average processing time: {np.mean(process_times)}")
print(f"Max processing time: {np.max(process_times)}")
print(f"Min processing time: {np.min(process_times)}")
print(f"Average processing time excepting first: {np.mean(process_times[1:])}")
# Out:
# Average processing time: 0.1965353012084961
# Max processing time: 1.8165664672851562
# Min processing time: 0.0159604549407959
# Average processing time excepting first: 0.01653183831108941

# %%
for c, l in enumerate(labels):
    for i in range(NUM_CLASSES):
        single_label = np.zeros((20, 20, 3))
        single_label[:, :, 0] = labels[c, :, :, i]
        single_label[:, :, 1] = labels[c, :, :, NUM_CLASSES+i*2]
        single_label[:, :, 2] = labels[c, :, :, NUM_CLASSES+1+i*2]
        
        anchors = get_anchors(320, 320, 20, 20)

        label_points = get_all_points_from_prediction(single_label,
                                                      anchors,
                                                      threshold=1.0,
                                                      offset_weight=OFFSET_SCALE)
        
        for p in label_points:
            x = p[0] + p[2]
            y = p[1] + p[3]
            
            #print(f"Label point: ({x}, {y})")
            #print(f"\tOffset: ({p[2]}, {p[3]})")
            print(f"Label point: ({x}, {y}), offset: ({p[2]}, {p[3]})")

            cv2.circle(images_show[c], (int(x), int(y)), 1, (0, 255, 0), thickness=2)
# Out:
# Label point: (154.5, 181.39999389648438), offset: (2.5, -0.600006103515625)
# Label point: (191.89999389648438, 148.6999969482422), offset: (-6.100006103515625, -3.3000030517578125)
# Label point: (183.3000030517578, 152.3000030517578), offset: (1.3000030517578125, 0.3000030517578125)
# Label point: (170.3000030517578, 156.1999969482422), offset: (3.3000030517578125, 4.1999969482421875)
# Label point: (163.10000610351562, 170.10000610351562), offset: (-3.899993896484375, 3.100006103515625)
# Label point: (215.39999389648438, 185.1999969482422), offset: (2.399993896484375, 3.1999969482421875)
# Label point: (205.39999389648438, 182.8000030517578), offset: (7.399993896484375, 0.8000030517578125)
# Label point: (194.3000030517578, 181.0), offset: (-3.6999969482421875, -1.0)
# Label point: (181.5, 177.10000610351562), offset: (-0.5, -4.899993896484375)
# Label point: (221.60000610351562, 186.10000610351562), offset: (-6.399993896484375, 4.100006103515625)
# Label point: (209.6999969482422, 188.10000610351562), offset: (-3.3000030517578125, 6.100006103515625)
# Label point: (197.1999969482422, 188.8000030517578), offset: (-0.8000030517578125, 6.8000030517578125)
# Label point: (182.89999389648438, 186.6999969482422), offset: (0.899993896484375, 4.6999969482421875)
# Label point: (217.0, 187.10000610351562), offset: (4.0, 5.100006103515625)
# Label point: (206.8000030517578, 190.89999389648438), offset: (-6.1999969482421875, -7.100006103515625)
# Label point: (195.39999389648438, 193.1999969482422), offset: (-2.600006103515625, -4.8000030517578125)
# Label point: (182.8000030517578, 192.5), offset: (0.8000030517578125, -5.5)
# Label point: (207.89999389648438, 192.0), offset: (-5.100006103515625, -6.0)
# Label point: (201.0, 195.5), offset: (3.0, -2.5)
# Label point: (194.60000610351562, 197.1999969482422), offset: (-3.399993896484375, -0.8000030517578125)
# Label point: (182.10000610351562, 197.1999969482422), offset: (0.100006103515625, -0.8000030517578125)
# Label point: (251.39999389648438, 181.3000030517578), offset: (-7.600006103515625, -0.6999969482421875)
# Label point: (276.0, 205.1999969482422), offset: (2.0, 7.1999969482421875)
# Label point: (270.29998779296875, 199.89999389648438), offset: (-3.70001220703125, 1.899993896484375)
# Label point: (265.1000061035156, 192.39999389648438), offset: (6.100006103515625, -5.600006103515625)
# Label point: (258.0, 185.3000030517578), offset: (-1.0, 3.3000030517578125)
# Label point: (281.8999938964844, 220.60000610351562), offset: (-7.100006103515625, -7.399993896484375)
# Label point: (279.3999938964844, 213.1999969482422), offset: (5.399993896484375, 0.1999969482421875)
# Label point: (276.8999938964844, 206.6999969482422), offset: (2.899993896484375, -6.3000030517578125)
# Label point: (271.1000061035156, 198.1999969482422), offset: (-2.899993896484375, 0.1999969482421875)
# Label point: (274.70001220703125, 222.8000030517578), offset: (0.70001220703125, -5.1999969482421875)
# Label point: (273.79998779296875, 215.89999389648438), offset: (-0.20001220703125, 2.899993896484375)
# Label point: (272.79998779296875, 208.60000610351562), offset: (-1.20001220703125, -4.399993896484375)
# Label point: (268.20001220703125, 200.0), offset: (-5.79998779296875, 2.0)
# Label point: (266.3999938964844, 221.10000610351562), offset: (7.399993896484375, -6.899993896484375)
# Label point: (266.5, 214.6999969482422), offset: (7.5, 1.6999969482421875)
# Label point: (266.29998779296875, 208.0), offset: (7.29998779296875, -5.0)
# Label point: (263.8999938964844, 200.39999389648438), offset: (4.899993896484375, 2.399993896484375)
# Label point: (258.70001220703125, 216.8000030517578), offset: (-0.29998779296875, 3.8000030517578125)
# Label point: (259.20001220703125, 212.39999389648438), offset: (0.20001220703125, -0.600006103515625)
# Label point: (259.6000061035156, 208.1999969482422), offset: (0.600006103515625, -4.8000030517578125)
# Label point: (257.8999938964844, 200.5), offset: (-1.100006103515625, 2.5)
# Label point: (153.1999969482422, 166.10000610351562), offset: (1.1999969482421875, -0.899993896484375)
# Label point: (189.60000610351562, 225.89999389648438), offset: (7.600006103515625, -2.100006103515625)
# Label point: (184.60000610351562, 211.5), offset: (2.600006103515625, -1.5)
# Label point: (184.89999389648438, 192.10000610351562), offset: (2.899993896484375, -5.899993896484375)
# Label point: (170.8000030517578, 175.1999969482422), offset: (3.8000030517578125, -6.8000030517578125)
# Label point: (185.5, 240.39999389648438), offset: (3.5, -2.600006103515625)
# Label point: (181.60000610351562, 232.6999969482422), offset: (-0.399993896484375, 4.6999969482421875)
# Label point: (176.8000030517578, 222.8000030517578), offset: (-5.1999969482421875, -5.1999969482421875)
# Label point: (171.0, 200.60000610351562), offset: (4.0, 2.600006103515625)
# Label point: (171.1999969482422, 239.1999969482422), offset: (4.1999969482421875, -3.8000030517578125)
# Label point: (166.60000610351562, 237.0), offset: (-0.399993896484375, -6.0)
# Label point: (161.5, 228.3000030517578), offset: (-5.5, 0.3000030517578125)
# Label point: (157.5, 205.5), offset: (5.5, 7.5)
# Label point: (159.0, 236.1999969482422), offset: (7.0, -6.8000030517578125)
# Label point: (153.3000030517578, 237.0), offset: (1.3000030517578125, -6.0)
# Label point: (147.60000610351562, 226.6999969482422), offset: (-4.399993896484375, -1.3000030517578125)
# Label point: (147.3000030517578, 207.3000030517578), offset: (-4.6999969482421875, -5.6999969482421875)
# Label point: (144.6999969482422, 237.39999389648438), offset: (-7.3000030517578125, -5.600006103515625)
# Label point: (138.8000030517578, 236.5), offset: (1.8000030517578125, -6.5)
# Label point: (134.60000610351562, 229.0), offset: (-2.399993896484375, 1.0)
# Label point: (138.0, 207.6999969482422), offset: (1.0, -5.3000030517578125)
# Label point: (304.0, 182.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 274.0), offset: (0.0, 0.0)
# Label point: (304.0, 228.0), offset: (0.0, 0.0)
# Label point: (304.0, 182.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 274.0), offset: (0.0, 0.0)
# Label point: (304.0, 228.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 243.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 274.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (304.0, 304.0), offset: (0.0, 0.0)
# Label point: (137.0, 144.6999969482422), offset: (0.0, -7.3000030517578125)
# Label point: (76.68000030517578, 113.30000305175781), offset: (0.6800003051757812, 7.3000030517578125)
# Label point: (87.6500015258789, 120.9000015258789), offset: (-3.3499984741210938, -0.09999847412109375)
# Label point: (102.0999984741211, 125.9000015258789), offset: (-3.9000015258789062, 4.900001525878906)
# Label point: (121.5999984741211, 134.39999389648438), offset: (0.5999984741210938, -2.600006103515625)
# Label point: (73.06999969482422, 129.0), offset: (-2.9300003051757812, 8.0)
# Label point: (88.01000213623047, 126.5999984741211), offset: (-2.9899978637695312, 5.599998474121094)
# Label point: (100.9000015258789, 125.0), offset: (-5.099998474121094, 4.0)
# Label point: (115.0999984741211, 125.9000015258789), offset: (-5.900001525878906, 4.900001525878906)
# Label point: (81.41000366210938, 149.6999969482422), offset: (5.410003662109375, -2.3000030517578125)
# Label point: (95.86000061035156, 144.3000030517578), offset: (4.8600006103515625, 7.3000030517578125)
# Label point: (109.69999694824219, 137.6999969482422), offset: (3.6999969482421875, 0.6999969482421875)
# Label point: (122.5, 135.0), offset: (1.5, -2.0)
# Label point: (90.18000030517578, 164.5), offset: (-0.8199996948242188, -2.5)
# Label point: (103.4000015258789, 157.8000030517578), offset: (-2.5999984741210938, 5.8000030517578125)
# Label point: (116.0999984741211, 150.89999389648438), offset: (-4.900001525878906, -1.100006103515625)
# Label point: (127.19999694824219, 144.1999969482422), offset: (6.1999969482421875, 7.1999969482421875)
# Label point: (104.80000305175781, 173.0), offset: (-1.1999969482421875, 6.0)
# Label point: (112.80000305175781, 167.89999389648438), offset: (6.8000030517578125, 0.899993896484375)
# Label point: (120.4000015258789, 163.10000610351562), offset: (-0.5999984741210938, -3.899993896484375)
# Label point: (130.5, 155.5), offset: (-6.5, 3.5)
# Label point: (109.5999984741211, 152.89999389648438), offset: (3.5999984741210938, 0.899993896484375)
# Label point: (150.3000030517578, 148.8000030517578), offset: (-1.6999969482421875, -3.1999969482421875)
# Label point: (144.60000610351562, 139.0), offset: (-7.399993896484375, 2.0)
# Label point: (128.89999389648438, 133.39999389648438), offset: (7.899993896484375, -3.600006103515625)
# Label point: (112.80000305175781, 140.3000030517578), offset: (6.8000030517578125, 3.3000030517578125)
# Label point: (162.10000610351562, 134.1999969482422), offset: (-4.899993896484375, -2.8000030517578125)
# Label point: (151.60000610351562, 137.6999969482422), offset: (-0.399993896484375, 0.6999969482421875)
# Label point: (139.6999969482422, 142.5), offset: (2.6999969482421875, 5.5)
# Label point: (124.19999694824219, 148.1999969482422), offset: (3.1999969482421875, -3.8000030517578125)
# Label point: (166.3000030517578, 153.89999389648438), offset: (-0.6999969482421875, 1.899993896484375)
# Label point: (155.0, 156.10000610351562), offset: (3.0, 4.100006103515625)
# Label point: (142.3000030517578, 158.3000030517578), offset: (5.3000030517578125, 6.3000030517578125)
# Label point: (128.60000610351562, 158.5), offset: (7.600006103515625, 6.5)
# Label point: (126.9000015258789, 158.5), offset: (5.900001525878906, 6.5)
# Label point: (137.39999389648438, 153.10000610351562), offset: (0.399993896484375, 1.100006103515625)
# Label point: (144.1999969482422, 156.8000030517578), offset: (7.1999969482421875, 4.8000030517578125)
# Label point: (132.10000610351562, 164.1999969482422), offset: (-4.899993896484375, -2.8000030517578125)
# Label point: (135.0, 162.89999389648438), offset: (-2.0, -4.100006103515625)
# Label point: (142.3000030517578, 158.60000610351562), offset: (5.3000030517578125, 6.600006103515625)
# Label point: (146.89999389648438, 160.6999969482422), offset: (-5.100006103515625, -6.3000030517578125)
# Label point: (136.10000610351562, 168.1999969482422), offset: (-0.899993896484375, 1.1999969482421875)
# Label point: (258.20001220703125, 221.10000610351562), offset: (-0.79998779296875, -6.899993896484375)
# Label point: (241.0, 254.60000610351562), offset: (-2.0, -4.399993896484375)
# Label point: (243.39999389648438, 247.39999389648438), offset: (0.399993896484375, 4.399993896484375)
# Label point: (245.60000610351562, 238.5), offset: (2.600006103515625, -4.5)
# Label point: (251.5, 227.60000610351562), offset: (-7.5, -0.399993896484375)
# Label point: (241.0, 267.70001220703125), offset: (-2.0, -6.29998779296875)
# Label point: (246.6999969482422, 262.79998779296875), offset: (3.6999969482421875, 3.79998779296875)
# Label point: (251.0, 257.29998779296875), offset: (8.0, -1.70001220703125)
# Label point: (254.0, 247.1999969482422), offset: (-5.0, 4.1999969482421875)
# Label point: (240.5, 263.3999938964844), offset: (-2.5, 4.399993896484375)
# Label point: (247.1999969482422, 260.8999938964844), offset: (4.1999969482421875, 1.899993896484375)
# Label point: (253.5, 257.0), offset: (-5.5, -2.0)
# Label point: (257.29998779296875, 247.8000030517578), offset: (-1.70001220703125, 4.8000030517578125)
# Label point: (240.6999969482422, 256.0), offset: (-2.3000030517578125, -3.0)
# Label point: (247.6999969482422, 255.39999389648438), offset: (4.6999969482421875, -3.600006103515625)
# Label point: (254.3000030517578, 252.6999969482422), offset: (-4.6999969482421875, -6.3000030517578125)
# Label point: (258.29998779296875, 245.6999969482422), offset: (-0.70001220703125, 2.6999969482421875)
# Label point: (244.10000610351562, 247.5), offset: (1.100006103515625, 4.5)
# Label point: (248.89999389648438, 248.89999389648438), offset: (5.899993896484375, 5.899993896484375)
# Label point: (253.39999389648438, 248.39999389648438), offset: (-5.600006103515625, 5.399993896484375)
# Label point: (257.8999938964844, 242.10000610351562), offset: (-1.100006103515625, -0.899993896484375)
# Label point: (204.5, 225.10000610351562), offset: (6.5, -2.899993896484375)
# Label point: (152.3000030517578, 144.10000610351562), offset: (0.3000030517578125, 7.100006103515625)
# Label point: (159.89999389648438, 173.89999389648438), offset: (-7.100006103515625, 6.899993896484375)
# Label point: (165.6999969482422, 197.6999969482422), offset: (-1.3000030517578125, -0.3000030517578125)
# Label point: (182.89999389648438, 216.5), offset: (0.899993896484375, 3.5)
# Label point: (165.6999969482422, 130.1999969482422), offset: (-1.3000030517578125, -6.8000030517578125)
# Label point: (164.39999389648438, 143.5), offset: (-2.600006103515625, 6.5)
# Label point: (164.8000030517578, 149.6999969482422), offset: (-2.1999969482421875, -2.3000030517578125)
# Label point: (165.39999389648438, 170.10000610351562), offset: (-1.600006103515625, 3.100006103515625)
# Label point: (187.39999389648438, 155.3000030517578), offset: (5.399993896484375, 3.3000030517578125)
# Label point: (185.5, 151.89999389648438), offset: (3.5, -0.100006103515625)
# Label point: (182.8000030517578, 143.89999389648438), offset: (0.8000030517578125, 6.899993896484375)
# Label point: (184.1999969482422, 163.0), offset: (2.1999969482421875, -4.0)
# Label point: (206.3000030517578, 171.6999969482422), offset: (-6.6999969482421875, 4.6999969482421875)
# Label point: (205.6999969482422, 162.1999969482422), offset: (-7.3000030517578125, -4.8000030517578125)
# Label point: (205.6999969482422, 152.5), offset: (-7.3000030517578125, 0.5)
# Label point: (202.8000030517578, 163.10000610351562), offset: (4.8000030517578125, -3.899993896484375)
# Label point: (228.89999389648438, 184.5), offset: (0.899993896484375, 2.5)
# Label point: (229.0, 168.10000610351562), offset: (1.0, 1.100006103515625)
# Label point: (227.8000030517578, 155.60000610351562), offset: (-0.1999969482421875, 3.600006103515625)
# Label point: (223.3000030517578, 167.1999969482422), offset: (-4.6999969482421875, 0.1999969482421875)
# Label point: (265.70001220703125, 135.39999389648438), offset: (6.70001220703125, -1.600006103515625)
# Label point: (192.0, 173.3000030517578), offset: (-6.0, 6.3000030517578125)
# Label point: (201.0, 159.8000030517578), offset: (3.0, -7.1999969482421875)
# Label point: (216.8000030517578, 144.39999389648438), offset: (3.8000030517578125, 7.399993896484375)
# Label point: (240.60000610351562, 138.3000030517578), offset: (-2.399993896484375, 1.3000030517578125)
# Label point: (192.60000610351562, 180.0), offset: (-5.399993896484375, -2.0)
# Label point: (193.39999389648438, 174.39999389648438), offset: (-4.600006103515625, 7.399993896484375)
# Label point: (194.0, 168.10000610351562), offset: (-4.0, 1.100006103515625)
# Label point: (202.39999389648438, 155.6999969482422), offset: (4.399993896484375, 3.6999969482421875)
# Label point: (183.5, 193.89999389648438), offset: (1.5, -4.100006103515625)
# Label point: (187.6999969482422, 187.0), offset: (5.6999969482421875, 5.0)
# Label point: (190.8000030517578, 179.1999969482422), offset: (-7.1999969482421875, -2.8000030517578125)
# Label point: (207.10000610351562, 166.6999969482422), offset: (-5.899993896484375, -0.3000030517578125)
# Label point: (205.6999969482422, 199.89999389648438), offset: (-7.3000030517578125, 1.899993896484375)
# Label point: (205.10000610351562, 192.89999389648438), offset: (7.100006103515625, -5.100006103515625)
# Label point: (204.1999969482422, 186.89999389648438), offset: (6.1999969482421875, 4.899993896484375)
# Label point: (216.1999969482422, 173.3000030517578), offset: (3.1999969482421875, 6.3000030517578125)
# Label point: (218.0, 203.5), offset: (5.0, 5.5)
# Label point: (219.10000610351562, 198.5), offset: (6.100006103515625, 0.5)
# Label point: (220.0, 193.89999389648438), offset: (7.0, -4.100006103515625)
# Label point: (229.1999969482422, 180.3000030517578), offset: (1.1999969482421875, -1.6999969482421875)
# Label point: (58.90999984741211, 44.93000030517578), offset: (-1.0900001525878906, -0.06999969482421875)
# Label point: (79.54000091552734, 11.729999542236328), offset: (3.5400009155273438, -3.270000457763672)
# Label point: (76.3499984741211, 25.559999465942383), offset: (0.34999847412109375, -4.440000534057617)
# Label point: (69.01000213623047, 33.65999984741211), offset: (-6.989997863769531, 3.6599998474121094)
# Label point: (91.12000274658203, 6.580999851226807), offset: (0.12000274658203125, -8.419000148773193)
# Label point: (63.459999084472656, 3.063999891281128), offset: (3.4599990844726562, -11.936000108718872)
# Label point: (88.66000366210938, 7.377999782562256), offset: (-2.339996337890625, -7.622000217437744)
# Label point: (84.54000091552734, 11.430000305175781), offset: (-6.459999084472656, -3.5699996948242188)
# Label point: (56.9900016784668, 0.8210999965667725), offset: (-3.009998321533203, -14.178900003433228)
# Label point: (79.44000244140625, 13.210000038146973), offset: (3.44000244140625, -1.7899999618530273)
# Label point: (73.79000091552734, 2.24399995803833), offset: (-2.2099990844726562, -12.75600004196167)
# Label point: (54.68000030517578, 4.460999965667725), offset: (-5.319999694824219, -10.539000034332275)
# Label point: (231.3000030517578, 114.5), offset: (3.3000030517578125, -6.5)
# Label point: (146.6999969482422, 143.0), offset: (-5.3000030517578125, 6.0)
# Label point: (162.1999969482422, 133.8000030517578), offset: (-4.8000030517578125, -3.1999969482421875)
# Label point: (181.0, 123.0999984741211), offset: (-1.0, 2.0999984741210938)
# Label point: (204.1999969482422, 117.9000015258789), offset: (6.1999969482421875, -3.0999984741210938)
# Label point: (136.3000030517578, 176.1999969482422), offset: (-0.6999969482421875, -5.8000030517578125)
# Label point: (145.89999389648438, 164.39999389648438), offset: (-6.100006103515625, -2.600006103515625)
# Label point: (157.10000610351562, 151.1999969482422), offset: (5.100006103515625, -0.8000030517578125)
# Label point: (172.10000610351562, 136.6999969482422), offset: (5.100006103515625, -0.3000030517578125)
# Label point: (138.3000030517578, 189.60000610351562), offset: (1.3000030517578125, 7.600006103515625)
# Label point: (151.6999969482422, 175.10000610351562), offset: (-0.3000030517578125, -6.899993896484375)
# Label point: (164.1999969482422, 162.10000610351562), offset: (-2.8000030517578125, -4.899993896484375)
# Label point: (179.1999969482422, 149.3000030517578), offset: (-2.8000030517578125, -2.6999969482421875)
# Label point: (150.8000030517578, 197.3000030517578), offset: (-1.1999969482421875, -0.6999969482421875)
# Label point: (162.6999969482422, 183.39999389648438), offset: (-4.3000030517578125, 1.399993896484375)
# Label point: (174.89999389648438, 170.39999389648438), offset: (-7.100006103515625, 3.399993896484375)
# Label point: (189.3000030517578, 156.89999389648438), offset: (7.3000030517578125, 4.899993896484375)
# Label point: (166.6999969482422, 201.89999389648438), offset: (-0.3000030517578125, 3.899993896484375)
# Label point: (176.60000610351562, 190.10000610351562), offset: (-5.399993896484375, -7.899993896484375)
# Label point: (186.8000030517578, 180.39999389648438), offset: (4.8000030517578125, -1.600006103515625)
# Label point: (202.89999389648438, 164.39999389648438), offset: (4.899993896484375, -2.600006103515625)
# Label point: (99.55999755859375, 80.86000061035156), offset: (-6.44000244140625, 4.8600006103515625)
# Label point: (134.0, 138.5), offset: (-3.0, 1.5)
# Label point: (129.8000030517578, 125.5), offset: (-7.1999969482421875, 4.5)
# Label point: (125.19999694824219, 110.30000305175781), offset: (4.1999969482421875, 4.3000030517578125)
# Label point: (116.19999694824219, 94.44000244140625), offset: (-4.8000030517578125, 3.44000244140625)
# Label point: (135.89999389648438, 156.1999969482422), offset: (-1.100006103515625, 4.1999969482421875)
# Label point: (130.6999969482422, 151.89999389648438), offset: (-6.3000030517578125, -0.100006103515625)
# Label point: (125.30000305175781, 143.6999969482422), offset: (4.3000030517578125, 6.6999969482421875)
# Label point: (120.0, 128.39999389648438), offset: (-1.0, 7.399993896484375)
# Label point: (130.8000030517578, 149.0), offset: (-6.1999969482421875, -3.0)
# Label point: (124.0999984741211, 149.1999969482422), offset: (3.0999984741210938, -2.8000030517578125)
# Label point: (116.80000305175781, 144.1999969482422), offset: (-4.1999969482421875, 7.1999969482421875)
# Label point: (110.9000015258789, 130.89999389648438), offset: (4.900001525878906, -6.100006103515625)
# Label point: (123.0, 138.3000030517578), offset: (2.0, 1.3000030517578125)
# Label point: (115.0999984741211, 142.10000610351562), offset: (-5.900001525878906, 5.100006103515625)
# Label point: (108.69999694824219, 139.6999969482422), offset: (2.6999969482421875, 2.6999969482421875)
# Label point: (103.4000015258789, 128.6999969482422), offset: (-2.5999984741210938, 7.6999969482421875)
# Label point: (111.9000015258789, 129.3000030517578), offset: (5.900001525878906, -7.6999969482421875)
# Label point: (108.0, 133.89999389648438), offset: (2.0, -3.100006103515625)
# Label point: (103.69999694824219, 134.3000030517578), offset: (-2.3000030517578125, -2.6999969482421875)
# Label point: (95.7300033569336, 124.5), offset: (4.730003356933594, 3.5)
# Label point: (171.8000030517578, 143.3000030517578), offset: (4.8000030517578125, 6.3000030517578125)
# Label point: (153.10000610351562, 181.89999389648438), offset: (1.100006103515625, -0.100006103515625)
# Label point: (145.39999389648438, 167.5), offset: (-6.600006103515625, 0.5)
# Label point: (145.3000030517578, 150.6999969482422), offset: (-6.6999969482421875, -1.3000030517578125)
# Label point: (155.3000030517578, 144.3000030517578), offset: (3.3000030517578125, 7.3000030517578125)
# Label point: (195.1999969482422, 226.6999969482422), offset: (-2.8000030517578125, -1.3000030517578125)
# Label point: (190.0, 198.3000030517578), offset: (8.0, 0.3000030517578125)
# Label point: (189.89999389648438, 176.60000610351562), offset: (7.899993896484375, -5.399993896484375)
# Label point: (181.39999389648438, 157.6999969482422), offset: (-0.600006103515625, 5.6999969482421875)
# Label point: (191.1999969482422, 261.1000061035156), offset: (-6.8000030517578125, 2.100006103515625)
# Label point: (198.1999969482422, 225.89999389648438), offset: (0.1999969482421875, -2.100006103515625)
# Label point: (201.89999389648438, 198.0), offset: (3.899993896484375, 0.0)
# Label point: (194.0, 174.10000610351562), offset: (-4.0, 7.100006103515625)
# Label point: (187.60000610351562, 262.70001220703125), offset: (5.600006103515625, 3.70001220703125)
# Label point: (197.1999969482422, 228.1999969482422), offset: (-0.8000030517578125, 0.1999969482421875)
# Label point: (201.89999389648438, 206.0), offset: (3.899993896484375, -7.0)
# Label point: (198.3000030517578, 185.0), offset: (0.3000030517578125, 3.0)
# Label point: (184.60000610351562, 253.3000030517578), offset: (2.600006103515625, -5.6999969482421875)
# Label point: (194.0, 233.39999389648438), offset: (-4.0, 5.399993896484375)
# Label point: (198.60000610351562, 218.8000030517578), offset: (0.600006103515625, 5.8000030517578125)
# Label point: (197.1999969482422, 193.8000030517578), offset: (-0.8000030517578125, -4.1999969482421875)
# Label point: (122.9000015258789, 160.89999389648438), offset: (1.9000015258789062, -6.100006103515625)
# Label point: (161.0, 128.10000610351562), offset: (-6.0, 7.100006103515625)
# Label point: (152.5, 134.6999969482422), offset: (0.5, -2.3000030517578125)
# Label point: (140.39999389648438, 139.89999389648438), offset: (3.399993896484375, 2.899993896484375)
# Label point: (128.89999389648438, 150.1999969482422), offset: (7.899993896484375, -1.8000030517578125)
# Label point: (185.60000610351562, 159.39999389648438), offset: (3.600006103515625, 7.399993896484375)
# Label point: (172.8000030517578, 160.60000610351562), offset: (5.8000030517578125, -6.399993896484375)
# Label point: (158.8000030517578, 163.10000610351562), offset: (6.8000030517578125, -3.899993896484375)
# Label point: (145.6999969482422, 160.8000030517578), offset: (-6.3000030517578125, -6.1999969482421875)
# Label point: (192.89999389648438, 170.6999969482422), offset: (-5.100006103515625, 3.6999969482421875)
# Label point: (178.5, 171.8000030517578), offset: (-3.5, 4.8000030517578125)
# Label point: (164.5, 174.10000610351562), offset: (-2.5, 7.100006103515625)
# Label point: (149.60000610351562, 170.5), offset: (-2.399993896484375, 3.5)
# Label point: (190.6999969482422, 173.1999969482422), offset: (-7.3000030517578125, 6.1999969482421875)
# Label point: (177.8000030517578, 176.60000610351562), offset: (-4.1999969482421875, -5.399993896484375)
# Label point: (164.6999969482422, 180.3000030517578), offset: (-2.3000030517578125, -1.6999969482421875)
# Label point: (151.60000610351562, 175.89999389648438), offset: (-0.399993896484375, -6.100006103515625)
# Label point: (185.6999969482422, 181.6999969482422), offset: (3.6999969482421875, -0.3000030517578125)
# Label point: (176.60000610351562, 183.5), offset: (-5.399993896484375, 1.5)
# Label point: (167.60000610351562, 185.6999969482422), offset: (0.600006103515625, 3.6999969482421875)
# Label point: (153.0, 179.39999389648438), offset: (1.0, -2.600006103515625)
# Label point: (196.1999969482422, 158.0), offset: (-1.8000030517578125, 6.0)
# Label point: (205.8000030517578, 121.0), offset: (-7.1999969482421875, 0.0)
# Label point: (204.10000610351562, 128.8000030517578), offset: (6.100006103515625, 7.8000030517578125)
# Label point: (201.1999969482422, 135.8000030517578), offset: (3.1999969482421875, -1.1999969482421875)
# Label point: (199.89999389648438, 146.39999389648438), offset: (1.899993896484375, -5.600006103515625)
# Label point: (202.39999389648438, 143.6999969482422), offset: (4.399993896484375, 6.6999969482421875)
# Label point: (211.10000610351562, 146.5), offset: (-1.899993896484375, -5.5)
# Label point: (221.60000610351562, 149.6999969482422), offset: (-6.399993896484375, -2.3000030517578125)
# Label point: (217.8000030517578, 149.8000030517578), offset: (4.8000030517578125, -2.1999969482421875)
# Label point: (194.0, 144.89999389648438), offset: (-4.0, -7.100006103515625)
# Label point: (205.1999969482422, 151.60000610351562), offset: (7.1999969482421875, -0.399993896484375)
# Label point: (216.6999969482422, 157.89999389648438), offset: (3.6999969482421875, 5.899993896484375)
# Label point: (217.39999389648438, 159.6999969482422), offset: (4.399993896484375, -7.3000030517578125)
# Label point: (190.6999969482422, 150.60000610351562), offset: (-7.3000030517578125, -1.399993896484375)
# Label point: (201.1999969482422, 157.89999389648438), offset: (3.1999969482421875, 5.899993896484375)
# Label point: (212.0, 165.3000030517578), offset: (-1.0, -1.6999969482421875)
# Label point: (213.39999389648438, 166.89999389648438), offset: (0.399993896484375, -0.100006103515625)
# Label point: (192.1999969482422, 159.3000030517578), offset: (-5.8000030517578125, 7.3000030517578125)
# Label point: (197.5, 166.10000610351562), offset: (-0.5, -0.899993896484375)
# Label point: (203.3000030517578, 172.60000610351562), offset: (5.3000030517578125, 5.600006103515625)
# Label point: (206.6999969482422, 173.60000610351562), offset: (-6.3000030517578125, 6.600006103515625)

# %%
THRESHOLD = 0.9

for c, r in enumerate(res):
    #print(r.shape)
    #pred = r.reshape(20, 20, 3)
    
    for i in range(NUM_CLASSES):
        pred = np.zeros((20, 20, 3))
        
        pred[:, :, 0] = res[c, :, :, i]
        pred[:, :, 1] = res[c, :, :, NUM_CLASSES+i*2]
        pred[:, :, 2] = res[c, :, :, NUM_CLASSES+1+i*2]
        
        #print(np.max(pred[:, :, 0]))
        
        anchors = get_anchors(320, 320, 20, 20)
        #max_val = np.max(pred[:,:,0])
        max_val = 0.9
        pred_point = get_all_points_from_prediction(pred,
                                                    anchors,
                                                    threshold=max_val,
                                                    offset_weight=OFFSET_SCALE,
                                                    is_label=False)
        
        for p in pred_point:
            x = p[0] + p[2]
            y = p[1] + p[3]
            
            print(f"Predicted point: ({x}, {y}), confidence: {max_val}")

            cv2.circle(images_show[c], (int(x), int(y)), 1, (255, 0, 0), thickness=1)
# Out:
# Predicted point: (210.52800607681274, 159.93857192993164), confidence: 0.9
# Predicted point: (226.72338724136353, 175.6272839307785), confidence: 0.9
# Predicted point: (197.63534832000732, 159.43304815888405), confidence: 0.9
# Predicted point: (214.5903787612915, 187.82075119018555), confidence: 0.9
# Predicted point: (204.83136177062988, 187.03103065490723), confidence: 0.9
# Predicted point: (219.83136177062988, 187.03103065490723), confidence: 0.9
# Predicted point: (189.36737251281738, 176.0551896095276), confidence: 0.9
# Predicted point: (205.36737251281738, 161.0551896095276), confidence: 0.9
# Predicted point: (205.36737251281738, 176.0551896095276), confidence: 0.9
# Predicted point: (206.8461799621582, 184.90862464904785), confidence: 0.9
# Predicted point: (206.8461799621582, 200.90862464904785), confidence: 0.9
# Predicted point: (206.3095909357071, 187.81011867523193), confidence: 0.9
# Predicted point: (199.28510761260986, 189.8336362838745), confidence: 0.9
# Predicted point: (190.06907700747252, 174.9991970062256), confidence: 0.9
# Predicted point: (190.06907700747252, 189.9991970062256), confidence: 0.9
# Predicted point: (207.7070279121399, 188.48040962219238), confidence: 0.9
# Predicted point: (266.36159324645996, 220.6347894668579), confidence: 0.9
# Predicted point: (266.9257001876831, 219.7524824142456), confidence: 0.9
# Predicted point: (175.78923070430756, 235.81081771850586), confidence: 0.9
# Predicted point: (159.98192310333252, 241.474449634552), confidence: 0.9
# Predicted point: (157.89747619628906, 230.746732711792), confidence: 0.9
# Predicted point: (148.24345588684082, 205.88416290283203), confidence: 0.9
# Predicted point: (144.82249641418457, 234.8858995437622), confidence: 0.9
# Predicted point: (159.82249641418457, 249.8858995437622), confidence: 0.9
# Predicted point: (144.9277458190918, 229.357666015625), confidence: 0.9
# Predicted point: (144.80125904083252, 220.16969913244247), confidence: 0.9
# Predicted point: (143.27543830871582, 205.37717473506927), confidence: 0.9
# Predicted point: (296.0853388309479, 296.465430110693), confidence: 0.9
# Predicted point: (296.3454512357712, 297.4296758174896), confidence: 0.9
# Predicted point: (296.0532221198082, 296.76418137550354), confidence: 0.9
# Predicted point: (296.76983112096786, 296.67465806007385), confidence: 0.9
# Predicted point: (300.09709310531616, 296.6586943268776), confidence: 0.9
# Predicted point: (296.22123023867607, 296.101649582386), confidence: 0.9
# Predicted point: (298.94422221183777, 298.0598018169403), confidence: 0.9
# Predicted point: (297.24316596984863, 296.4325089454651), confidence: 0.9
# Predicted point: (303.31628704071045, 296.06044068932533), confidence: 0.9
# Predicted point: (100.57901048660278, 113.21231174468994), confidence: 0.9
# Predicted point: (81.93283176422119, 144.5130821466446), confidence: 0.9
# Predicted point: (122.33122730255127, 131.49116706848145), confidence: 0.9
# Predicted point: (95.64166831970215, 163.29144525527954), confidence: 0.9
# Predicted point: (127.93072891235352, 144.93585163354874), confidence: 0.9
# Predicted point: (114.39899635314941, 164.04875802993774), confidence: 0.9
# Predicted point: (144.67102909088135, 159.06501047313213), confidence: 0.9
# Predicted point: (144.5118989944458, 162.28896236419678), confidence: 0.9
# Predicted point: (144.62176418304443, 162.44919729232788), confidence: 0.9
# Predicted point: (132.0056574344635, 161.03886890411377), confidence: 0.9
# Predicted point: (251.02510092779994, 220.0370766632259), confidence: 0.9
# Predicted point: (247.69682121276855, 253.90415620803833), confidence: 0.9
# Predicted point: (250.07772159576416, 250.9970293045044), confidence: 0.9
# Predicted point: (250.99678325653076, 235.51660561561584), confidence: 0.9
# Predicted point: (251.00262613315135, 221.3752977848053), confidence: 0.9
# Predicted point: (249.41909980773926, 266.5557060241699), confidence: 0.9
# Predicted point: (249.41909980773926, 281.5557060241699), confidence: 0.9
# Predicted point: (250.98016166687012, 263.87921047210693), confidence: 0.9
# Predicted point: (250.99998664855957, 251.13482676446438), confidence: 0.9
# Predicted point: (251.00754349166527, 250.9962339401245), confidence: 0.9
# Predicted point: (250.8818826675415, 263.99457454681396), confidence: 0.9
# Predicted point: (250.99959754943848, 254.56159806251526), confidence: 0.9
# Predicted point: (251.00263723474927, 251.36967384815216), confidence: 0.9
# Predicted point: (251.10438219457865, 250.9961233139038), confidence: 0.9
# Predicted point: (251.0000783731448, 264.3601760864258), confidence: 0.9
# Predicted point: (251.00314071890898, 251.21320235729218), confidence: 0.9
# Predicted point: (254.30261158943176, 250.98103713989258), confidence: 0.9
# Predicted point: (250.6735200881958, 250.99175453186035), confidence: 0.9
# Predicted point: (250.6735200881958, 266.99175453186035), confidence: 0.9
# Predicted point: (250.99572277069092, 250.99789810180664), confidence: 0.9
# Predicted point: (250.99999809265137, 250.96758556365967), confidence: 0.9
# Predicted point: (256.40032386779785, 250.6311731338501), confidence: 0.9
# Predicted point: (222.64195275306702, 173.23706817626953), confidence: 0.9
# Predicted point: (209.64525699615479, 170.5204257965088), confidence: 0.9
# Predicted point: (224.64525699615479, 155.5204257965088), confidence: 0.9
# Predicted point: (239.64525699615479, 140.5204257965088), confidence: 0.9
# Predicted point: (191.47826373577118, 173.49814701080322), confidence: 0.9
# Predicted point: (198.41875076293945, 159.69603395462036), confidence: 0.9
# Predicted point: (196.2790732383728, 188.47314834594727), confidence: 0.9
# Predicted point: (200.25671863555908, 180.57851266860962), confidence: 0.9
# Predicted point: (205.4326572418213, 174.75801610946655), confidence: 0.9
# Predicted point: (205.11963498592377, 173.25323867797852), confidence: 0.9
# Predicted point: (205.00708484649658, 195.23775243759155), confidence: 0.9
# Predicted point: (214.78617572784424, 174.6190242767334), confidence: 0.9
# Predicted point: (205.4062438905239, 205.8661241531372), confidence: 0.9
# Predicted point: (206.31260573863983, 205.71979427337646), confidence: 0.9
# Predicted point: (213.8842010498047, 204.02154922485352), confidence: 0.9
# Predicted point: (220.40657711029053, 191.51479125022888), confidence: 0.9
# Predicted point: (235.40657711029053, 175.51479125022888), confidence: 0.9
# Predicted point: (53.444779753685, 45.81452751159668), confidence: 0.9
# Predicted point: (83.01603605225682, 7.000973388319835), confidence: 0.9
# Predicted point: (83.07371543347836, 7.39235046505928), confidence: 0.9
# Predicted point: (83.88877010345459, 22.010913922451437), confidence: 0.9
# Predicted point: (67.74349784851074, 37.14029349386692), confidence: 0.9
# Predicted point: (66.01397800445557, 8.12943422794342), confidence: 0.9
# Predicted point: (205.0347185060382, 113.9784984588623), confidence: 0.9
# Predicted point: (126.2467098236084, 113.71835708618164), confidence: 0.9
# Predicted point: (132.58978056907654, 159.35070419311523), confidence: 0.9
# Predicted point: (129.20037178695202, 148.12017393112183), confidence: 0.9
# Predicted point: (127.58999061584473, 135.30679416656494), confidence: 0.9
# Predicted point: (129.0139325549826, 158.5204496383667), confidence: 0.9
# Predicted point: (128.93096351623535, 145.19951677322388), confidence: 0.9
# Predicted point: (113.24011267721653, 144.469708442688), confidence: 0.9
# Predicted point: (109.17456531524658, 129.58440160751343), confidence: 0.9
# Predicted point: (106.91157817840576, 142.8304100036621), confidence: 0.9
# Predicted point: (98.74812030792236, 138.27000999450684), confidence: 0.9
# Predicted point: (98.217649102211, 134.17069911956787), confidence: 0.9
# Predicted point: (191.186927318573, 248.8001766204834), confidence: 0.9
# Predicted point: (190.4391241967678, 250.04281044006348), confidence: 0.9
# Predicted point: (196.27829217910767, 202.69047164916992), confidence: 0.9
# Predicted point: (200.04759979248047, 186.1019639968872), confidence: 0.9
# Predicted point: (144.98781967163086, 142.61763954162598), confidence: 0.9
# Predicted point: (144.84080982208252, 144.0854368209839), confidence: 0.9
# Predicted point: (207.6791067123413, 136.8599772453308), confidence: 0.9
# Predicted point: (209.45052576065063, 148.08221817016602), confidence: 0.9
# Predicted point: (208.66840958595276, 143.30739784240723), confidence: 0.9
# Predicted point: (206.3802615404129, 138.32277584075928), confidence: 0.9
# Predicted point: (197.4534945487976, 158.40267753601074), confidence: 0.9
# Predicted point: (207.4874074459076, 155.4027557373047), confidence: 0.9
# Predicted point: (213.56000423431396, 156.60212993621826), confidence: 0.9
# Predicted point: (217.11490631103516, 159.20895852148533), confidence: 0.9
# Predicted point: (215.97750663757324, 165.47413635253906), confidence: 0.9
# Predicted point: (209.5195436477661, 163.2504916191101), confidence: 0.9

# %%
def confidence_score(label, prediction, num_classes):
    """
    How often does the model tag the correct anchor.
    """
    error = 0
    for i in range(num_classes):
        l = label[:, :, i]
        p = prediction[:, :, i]
        
        label_x, label_y = np.where(l==1.0)
        try:
            label_point = np.array([label_x[0], label_y[0]])
            print(f"label_point: {label_point}")
        except:
            print("Error")
            continue

        prediction_x, prediction_y = np.where(p==np.max(p))
        prediction_point = np.array([prediction_x[0], prediction_y[0]])
        
        print(f"prediction_point: {prediction_point}")
        
        label_error = np.linalg.norm(label_point - prediction_point)
        error += label_error
        print(label_error)
        
        print("")
    
    return error

#print(res.shape)
confidence_score(labels[0], res[0], 42)
# Out:
# label_point: [ 9 11]
# prediction_point: [11  9]
# 2.8284271247461903
#
# label_point: [12  9]
# prediction_point: [13  9]
# 1.0
#
# label_point: [11  9]
# prediction_point: [12  9]
# 1.0
#
# label_point: [10  9]
# prediction_point: [12  9]
# 2.0
#
# label_point: [10 10]
# prediction_point: [11  9]
# 1.4142135623730951
#
# label_point: [13 11]
# prediction_point: [14 11]
# 1.0
#
# label_point: [12 11]
# prediction_point: [13 11]
# 1.0
#
# label_point: [12 11]
# prediction_point: [12 11]
# 0.0
#
# label_point: [11 11]
# prediction_point: [12 10]
# 1.4142135623730951
#
# label_point: [14 11]
# prediction_point: [13 11]
# 1.0
#
# label_point: [13 11]
# prediction_point: [13 11]
# 0.0
#
# label_point: [12 11]
# prediction_point: [13 11]
# 1.0
#
# label_point: [11 11]
# prediction_point: [12 10]
# 1.4142135623730951
#
# label_point: [13 11]
# prediction_point: [13 11]
# 0.0
#
# label_point: [13 12]
# prediction_point: [13 11]
# 1.0
#
# label_point: [12 12]
# prediction_point: [12 11]
# 1.0
#
# label_point: [11 12]
# prediction_point: [12 11]
# 1.4142135623730951
#
# label_point: [13 12]
# prediction_point: [13 11]
# 1.0
#
# label_point: [12 12]
# prediction_point: [13 11]
# 1.4142135623730951
#
# label_point: [12 12]
# prediction_point: [12 12]
# 0.0
#
# label_point: [11 12]
# prediction_point: [12 11]
# 1.4142135623730951
#
# label_point: [16 11]
# prediction_point: [16 11]
# 0.0
#
# label_point: [17 12]
# prediction_point: [17 12]
# 0.0
#
# label_point: [17 12]
# prediction_point: [17 12]
# 0.0
#
# label_point: [16 12]
# prediction_point: [15 12]
# 1.0
#
# label_point: [16 11]
# prediction_point: [15 12]
# 1.4142135623730951
#
# label_point: [18 14]
# prediction_point: [16 14]
# 2.0
#
# label_point: [17 13]
# prediction_point: [17 13]
# 0.0
#
# label_point: [17 13]
# prediction_point: [17 13]
# 0.0
#
# label_point: [17 12]
# prediction_point: [17 12]
# 0.0
#
# label_point: [17 14]
# prediction_point: [17 15]
# 1.0
#
# label_point: [17 13]
# prediction_point: [17 13]
# 0.0
#
# label_point: [17 13]
# prediction_point: [17 13]
# 0.0
#
# label_point: [17 12]
# prediction_point: [16 12]
# 1.0
#
# label_point: [16 14]
# prediction_point: [16 14]
# 0.0
#
# label_point: [16 13]
# prediction_point: [16 13]
# 0.0
#
# label_point: [16 13]
# prediction_point: [16 13]
# 0.0
#
# label_point: [16 12]
# prediction_point: [16 12]
# 0.0
#
# label_point: [16 13]
# prediction_point: [16 13]
# 0.0
#
# label_point: [16 13]
# prediction_point: [16 13]
# 0.0
#
# label_point: [16 13]
# prediction_point: [16 13]
# 0.0
#
# label_point: [16 12]
# prediction_point: [16 12]
# 0.0
# 28.72792206135786

# %%
p1 = np.array([9, 13])
p2 = np.array([10, 11])
print(np.linalg.norm(p1-p2))
# Out:
# 2.23606797749979

# %%
def accuracy():
    pass

# %%
f, subs = plt.subplots(len(images_show), 1, figsize=(15, 8*len(samples_to_check)))
for c, im in enumerate(images_show):
    subs[c].imshow(im)
    #subs[c].set_title(f"Confidence: {np.max(res[c][:,:,:,0])}")

#f = plt.figure(figsize=(20, 20))
#plt.imshow(images_show[0], cmap='gray')
