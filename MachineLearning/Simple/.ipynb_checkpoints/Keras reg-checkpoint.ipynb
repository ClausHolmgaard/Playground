# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras.models import Model
from keras import optimizers

# %%
num_data = 100
a = 2
b = 30
noise_scale = 20

# %%
x = np.linspace(-100, 100, num=num_data)
y = a*x + b

noise = np.random.normal(size=num_data)
y = y + noise_scale * noise
plt.scatter(x, y)

# %%
inp = Input(shape=(1,), name="input")
h = Dense(units=1)(inp)
model = Model(inputs=inp, outputs=h)

opt = optimizers.Adam(lr=1e-1)
model.compile(loss='mean_squared_error', optimizer=opt)

# %%
prev_ind = 0
epochs = 100
plot_cols = 3
num_plots = 9

plot_rows = int(num_plots/plot_cols)
f, subs = plt.subplots(plot_cols, plot_rows, figsize=(15, 4*plot_rows))
subs = subs.ravel()
plot_counter = 0

for i in range(epochs):
    
    #reg = LinearRegression().fit(x_slice.reshape(-1, 1), y_slice.reshape(-1, 1))
    #a_predict = reg.coef_[0][0]
    #b_predict = reg.intercept_[0]
    #y_predict = reg.predict(x.reshape(-1, 1))
    model.fit(x, y)
    y_predict = model.predict(x)

    #subs[counter].set_title(f"iteration: {counter}  a: {a_predict:.2f}, b: {b_predict:.2f}")
    subs[counter].scatter(x, y_predict)
    subs[counter].scatter(x, y, c='green')
    
    plot_counter += 1
# Out:
# Epoch 1/1
# 100/100 [==============================] - 0s 96us/step - loss: 878.2010
# Epoch 1/1
# 100/100 [==============================] - 0s 86us/step - loss: 860.6467
# Epoch 1/1
# 100/100 [==============================] - 0s 99us/step - loss: 861.7943
# Epoch 1/1
# 100/100 [==============================] - 0s 87us/step - loss: 836.4855
# Epoch 1/1
# 100/100 [==============================] - 0s 92us/step - loss: 821.1997
# Epoch 1/1
# 100/100 [==============================] - 0s 79us/step - loss: 824.3978
# Epoch 1/1
# 100/100 [==============================] - 0s 78us/step - loss: 797.0694
# Epoch 1/1
# 100/100 [==============================] - 0s 69us/step - loss: 778.6767
# Epoch 1/1
# 100/100 [==============================] - 0s 70us/step - loss: 789.8091
# Epoch 1/1
# 100/100 [==============================] - 0s 63us/step - loss: 768.1770
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-5f42da053882> in <module>
#      19
#      20     #subs[counter].set_title(f"iteration: {counter}  a: {a_predict:.2f}, b: {b_predict:.2f}")
# ---> 21     subs[counter].scatter(x, y_predict)
#      22     subs[counter].scatter(x, y, c='green')
#      23
#
# IndexError: index 9 is out of bounds for axis 0 with size 9
