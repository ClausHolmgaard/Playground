# %%
from Kinect import Kinect
import matplotlib.pyplot as plt
from pyntcloud import PyntCloud as pc

# %%
k = Kinect(debug=True,
           color=True,
           depth=True,
           ir=True,
           registered=True,
           undistorted=True)

# %%
k.start()
k.wait_for_init()
# Out:
# Packet pipeline: OpenCLPacketPipeline
# Number of devices: 1
# Init done

# %%
point_cloud = k.get_pointcloud()
color = k.get_color_image()
depth = k.get_depth_image()
ir = k.get_ir_image()
registered = k.get_registered_image()
undistorted = k.get_undistorted_image()

# %%
plt.imshow(color)

# %%
plt.imshow(ir, cmap='gray')

# %%
plt.imshow(registered)

# %%
plt.imshow(undistorted)

# %%
point_cloud.shape
# Out:
# (64204, 6)

# %%
points = pd.DataFrame(poi, columns=['x', 'y', 'z', 'red', 'green', 'blue'])
points.describe()

# %%
#k.stop()
